# %% [markdown]
# # Notebook 00 — Environment Check
#
# Verify GPU availability, package versions, and set deterministic seeds.

# %%
import sys, os, random
import numpy as np
import tensorflow as tf

# ── Deterministic seeds ──────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

print(f'Python  : {sys.version}')
print(f'NumPy   : {np.__version__}')
print(f'TF      : {tf.__version__}')

# %%
# ── GPU check ────────────────────────────────────────────────────
gpus = tf.config.list_physical_devices('GPU')
print(f'GPUs available: {len(gpus)}')
for g in gpus:
    print(f'  {g}')

if gpus:
    # Allow memory growth
    for g in gpus:
        tf.config.experimental.set_memory_growth(g, True)
    print('Memory growth enabled')

# %%
# ── Required packages ────────────────────────────────────────────
import pydicom
import SimpleITK as sitk
import sklearn
import matplotlib
import PIL
import pandas as pd

print(f'pydicom     : {pydicom.__version__}')
print(f'SimpleITK   : {sitk.Version_MajorVersion()}.{sitk.Version_MinorVersion()}')
print(f'scikit-learn: {sklearn.__version__}')
print(f'matplotlib  : {matplotlib.__version__}')
print(f'Pillow      : {PIL.__version__}')
print(f'pandas      : {pd.__version__}')

# %%
# ── Utils import check ───────────────────────────────────────────
sys.path.insert(0, os.path.dirname(os.path.abspath('')))
sys.path.insert(0, os.path.abspath('.'))

from utils import dicom_utils, rtstruct_utils, preprocess_utils
from utils import tfdata_utils, model_utils, eval_utils

print('\n✅ All utility modules imported successfully!')

# %%
# ── Dataset path check ───────────────────────────────────────────
DATASET_ROOT = '/path/to/local/resource'
CLINICAL_CSV = '/path/to/local/resource'

assert os.path.isdir(DATASET_ROOT), f'Dataset not found: {DATASET_ROOT}'
assert os.path.isfile(CLINICAL_CSV), f'Clinical CSV not found: {CLINICAL_CSV}'

patients = sorted([d for d in os.listdir(DATASET_ROOT)
                    if d.startswith('LUNG1-')])
print(f'Dataset OK: {len(patients)} patients found')
print(f'Clinical CSV OK: {CLINICAL_CSV}')
